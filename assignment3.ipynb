# %%
import requests
import collections
from bs4 import BeautifulSoup
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from urllib.parse import urljoin
#相对路径转绝对路径
def absolute_urls(url,relative_url):
    return urljoin(url,relative_url)

# %%
def get_source_page_html(urls):
    headers = {"User-Agent" : "User-Agent:Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0;"}
    r = requests.get(urls, headers=headers).content.decode('utf8')
    return r

# %%
def list_stations(each_line_souce_page):
    ##很难用一种过滤方式找到正确的所有站点，这里用了笨的办法，用两种过滤方式，然后用Max,每条线取找到最多站点的。
    soup=BeautifulSoup(each_line_souce_page,'html.parser')
    eachline_stations_one=[]
    eachline_stations_two=[]
    eachline_stations=[]

    x=soup.find_all('table',attrs={'data-sort':'sortDisabled'})
    for table in x:
        title=table.find('caption')
        if title==None:continue
        if title.string==None:continue
        if title.string[-1]=="表":
            stationlist=table.find_all('a')
            for i in stationlist:
                if i.string==None:continue
                if i.string[-1] =='站':
                    eachline_stations_one.append(i.string)
    y=soup.find('table',attrs={'data-sort':'sortDisabled'})
    stationlist_two = y.find_all('a')
    for i in stationlist_two:
        if i.string == None: continue
        if i.string[-1] == '站':
            eachline_stations_two.append(i.string)
    return max(eachline_stations_one,eachline_stations_two,key=lambda k: len(k))


def find_lines_with_stations():
    lines_and_stations=collections.defaultdict(list)
    url='https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81/408485'
    soup = BeautifulSoup(get_source_page_html(url), 'html.parser')
    table=soup.find('table',attrs={'width':'658'})
    lines=table.find_all('a')
    lines.pop()
    for line in lines:
        lines_and_stations[line.string]=list_stations(get_source_page_html(absolute_urls(url,(line.get('href')))))
    return lines_and_stations

# %%
t=find_lines_with_stations()
t
# Out:
# defaultdict(list,
#             {'北京地铁1号线': ['黑石头站',
#               '高井站',
#               '福寿岭站',
#               '苹果园站',
#               '古城站',
#               '八角游乐园站',
#               '八宝山站',
#               '玉泉路站',
#               '五棵松站',
#               '万寿路站',
#               '公主坟站',
#               '军事博物馆站',
#               '木樨地站',
#               '南礼士路站',
#               '复兴门站',
#               '西单站',
#               '天安门西站',
#               '天安门东站',
#               '王府井站',
#               '东单站',
#               '建国门站',
#               '永安里站',
#               '国贸站',
#               '大望路站',
#               '四惠站',
#               '四惠东站'],
#              '北京地铁2号线': ['西直门站',
#               '积水潭站',
#               '鼓楼大街站',
#               '安定门站',
#               '雍和宫站',
#               '东直门站',
#               '东四十条站',
#               '朝阳门站',
#               '建国门站',
#               '北京站',
#               '崇文门站',
#               '前门站',
#               '和平门站',
#               '宣武门站',
#               '长椿街站',
#               '复兴门站',
#               '阜成门站',
#               '车公庄站'],
#              '北京地铁4号线': ['天宫院站',
#               '安河桥北站',
#               '天宫院站',
#               '生物医药基地站',
#               '义和庄站',
#               '黄村火车站',
#               '黄村西大街站',
#               '清源路站',
#               '枣园站',
#               '高米店南站',
#               '高米店北站',
#               '西红门站',
#               '新宫站',
#               '公益西桥站',
#               '角门西站',
#               '马家堡站',
#               '北京南站',
#               '陶然亭站',
#               '菜市口站',
#               '宣武门站',
#               '西单站',
#               '灵境胡同站',
#               '西四站',
#               '平安里站',
#               '新街口站',
#               '西直门站',
#               '动物园站',
#               '国家图书馆站',
#               '魏公村站',
#               '人民大学站',
#               '海淀黄庄站',
#               '中关村站',
#               '北京大学东门站',
#               '圆明园站',
#               '西苑站',
#               '北宫门站',
#               '安河桥北站'],
#              '北京地铁5号线': ['宋家庄站',
#               '刘家窑站',
#               '蒲黄榆站',
#               '天坛东门站',
#               '磁器口站',
#               '崇文门站',
#               '东单站',
#               '灯市口站',
#               '东四站',
#               '张自忠路站',
#               '北新桥站',
#               '雍和宫站',
#               '和平里北街站',
#               '和平西桥站',
#               '惠新西街南口站',
#               '惠新西街北口站',
#               '大屯路东站',
#               '北苑路北站',
#               '立水桥南站',
#               '立水桥站',
#               '天通苑南站',
#               '天通苑站',
#               '天通苑北站'],
#              '北京地铁6号线': ['金安桥站',
#               '苹果园站',
#               '田村站',
#               '海淀五路居站',
#               '慈寿寺站',
#               '花园桥站',
#               '白石桥南站',
#               '二里沟站',
#               '车公庄西站',
#               '车公庄站',
#               '平安里站',
#               '北海北站',
#               '南锣鼓巷站',
#               '东四站',
#               '朝阳门站',
#               '东大桥站',
#               '呼家楼站',
#               '金台路站',
#               '十里堡站',
#               '青年路站',
#               '褡裢坡站',
#               '黄渠站',
#               '常营站',
#               '草房站',
#               '物资学院路站',
#               '通州北关站',
#               '通运门站',
#               '北运河西站',
#               '北运河东站',
#               '郝家府站',
#               '东夏园站',
#               '潞城站'],
#              '北京地铁7号线': ['北京西站',
#               '湾子站',
#               '达官营站',
#               '广安门内站',
#               '菜市口站',
#               '虎坊桥站',
#               '珠市口站',
#               '桥湾站',
#               '磁器口站',
#               '广渠门内站',
#               '广渠门外站',
#               '双井站',
#               '九龙山站',
#               '大郊亭站',
#               '百子湾站',
#               '化工站',
#               '南楼梓庄站',
#               '欢乐谷景区站',
#               '垡头站',
#               '双合站',
#               '焦化厂站',
#               '豆各庄站'],
#              '北京地铁8号线': ['朱辛庄站',
#               '育知路站',
#               '平西府站',
#               '回龙观东大街站',
#               '霍营站',
#               '育新站',
#               '西小口站',
#               '永泰庄站',
#               '林萃桥站',
#               '森林公园南门站',
#               '奥林匹克公园站',
#               '奥体中心站',
#               '北土城站',
#               '安华桥站',
#               '安德里北街站',
#               '鼓楼大街站',
#               '什刹海站',
#               '南锣鼓巷站',
#               '中国美术馆站',
#               '王府井站',
#               '前门站',
#               '珠市口站',
#               '天桥站',
#               '永定门外站',
#               '木樨园站',
#               '海户屯站',
#               '大红门站',
#               '大红门南站',
#               '和义站',
#               '东高地站',
#               '火箭万源站',
#               '五福堂站',
#               '德茂站',
#               '瀛海站'],
#              '北京地铁9号线': ['郭公庄站',
#               '丰台科技园站',
#               '科怡路站',
#               '丰台南路站',
#               '丰台东大街站',
#               '七里庄站',
#               '六里桥站',
#               '六里桥东站',
#               '北京西站',
#               '军事博物馆站',
#               '白堆子站',
#               '白石桥南站',
#               '国家图书馆站'],
#              '北京地铁10号线': ['巴沟站',
#               '苏州街站',
#               '海淀黄庄站',
#               '知春里站',
#               '知春路站',
#               '西土城站',
#               '牡丹园站',
#               '健德门站',
#               '北土城站',
#               '安贞门站',
#               '惠新西街南口站',
#               '芍药居站',
#               '太阳宫站',
#               '三元桥站',
#               '亮马桥站',
#               '农业展览馆站',
#               '团结湖站',
#               '呼家楼站',
#               '金台夕照站',
#               '国贸站',
#               '双井站',
#               '劲松站',
#               '潘家园站',
#               '十里河站',
#               '分钟寺站',
#               '成寿寺站',
#               '宋家庄站',
#               '石榴庄站',
#               '大红门站',
#               '角门东站',
#               '角门西站',
#               '草桥站',
#               '纪家庙站',
#               '首经贸站',
#               '丰台站',
#               '泥洼站',
#               '西局站',
#               '六里桥站',
#               '莲花桥站',
#               '公主坟站',
#               '西钓鱼台站',
#               '慈寿寺站',
#               '车道沟站',
#               '长春桥站',
#               '火器营站',
#               '巴沟站'],
#              '北京地铁13号线': ['西直门站',
#               '大钟寺站',
#               '知春路站',
#               '五道口站',
#               '清华东路西口站',
#               '上地站',
#               '清河站',
#               '西二旗站',
#               '龙泽站',
#               '回龙观站',
#               '霍营站',
#               '建材城东路站',
#               '立水桥站',
#               '北苑站',
#               '望京西站',
#               '芍药居站',
#               '光熙门站',
#               '柳芳站',
#               '东直门站'],
#              '北京地铁14号线': ['园博园站',
#               '大瓦窑站',
#               '郭庄子站',
#               '大井站',
#               '七里庄站',
#               '西局站',
#               '丽泽商务区站',
#               '北京南站',
#               '陶然桥站',
#               '永定门外站',
#               '景泰站',
#               '蒲黄榆站',
#               '方庄站',
#               '十里河站',
#               '北工大西门站',
#               '平乐园站',
#               '九龙山站',
#               '大望路站',
#               '金台路站',
#               '朝阳公园站',
#               '枣营站',
#               '东风北桥站',
#               '将台站',
#               '高家园站',
#               '望京南站',
#               '阜通站',
#               '望京站',
#               '东湖渠站',
#               '来广营站',
#               '善各庄站'],
#              '北京地铁15号线': ['清华东路西口站',
#               '六道口站',
#               '北沙滩站',
#               '奥林匹克公园站',
#               '安立路站',
#               '大屯路东站',
#               '关庄站',
#               '望京西站',
#               '望京站',
#               '望京东站',
#               '崔各庄站',
#               '马泉营站',
#               '孙河站',
#               '国展站',
#               '花梨坎站',
#               '后沙峪站',
#               '南法信站',
#               '石门站',
#               '顺义站',
#               '俸伯站'],
#              '北京地铁16号线': [],
#              '北京地铁八通线': ['四惠站',
#               '四惠东站',
#               '高碑店站',
#               '传媒大学站',
#               '双桥站',
#               '管庄站',
#               '八里桥站',
#               '通州北苑站',
#               '果园站',
#               '九棵树站',
#               '梨园站',
#               '临河里站',
#               '土桥站',
#               '环球影城站'],
#              '北京地铁昌平线': ['西二旗站',
#               '生命科学园站',
#               '朱辛庄站',
#               '巩华城站',
#               '沙河站',
#               '沙河高教园站',
#               '南邵站',
#               '北邵洼站',
#               '昌平东关站',
#               '昌平站',
#               '昌平北站',
#               '十三陵景区站',
#               '昌平西山口站'],
#              '北京地铁亦庄线': ['亦庄火车站',
#               '次渠站',
#               '次渠南站',
#               '经海路站',
#               '同济南路站',
#               '荣昌东街站',
#               '荣京东街站',
#               '万源街站',
#               '亦庄文化园站',
#               '亦庄桥站',
#               '旧宫站',
#               '小红门站',
#               '肖村站',
#               '宋家庄站'],
#              '北京地铁房山线': ['阎村东站',
#               '苏庄站',
#               '良乡南关站',
#               '良乡大学城西站',
#               '良乡大学城站',
#               '良乡大学城北站',
#               '广阳城站',
#               '篱笆房站',
#               '长阳站',
#               '稻田站',
#               '大葆台站',
#               '郭公庄站',
#               '首经贸站',
#               '丰益桥南站']})

# %%
l=t.values()

# %%
allstations=[]
for i in l:
    for x in i:
        allstations.append(x)

# %%
allstations
# Out:
# ['黑石头站',
#  '高井站',
#  '福寿岭站',
#  '苹果园站',
#  '古城站',
#  '八角游乐园站',
#  '八宝山站',
#  '玉泉路站',
#  '五棵松站',
#  '万寿路站',
#  '公主坟站',
#  '军事博物馆站',
#  '木樨地站',
#  '南礼士路站',
#  '复兴门站',
#  '西单站',
#  '天安门西站',
#  '天安门东站',
#  '王府井站',
#  '东单站',
#  '建国门站',
#  '永安里站',
#  '国贸站',
#  '大望路站',
#  '四惠站',
#  '四惠东站',
#  '西直门站',
#  '积水潭站',
#  '鼓楼大街站',
#  '安定门站',
#  '雍和宫站',
#  '东直门站',
#  '东四十条站',
#  '朝阳门站',
#  '建国门站',
#  '北京站',
#  '崇文门站',
#  '前门站',
#  '和平门站',
#  '宣武门站',
#  '长椿街站',
#  '复兴门站',
#  '阜成门站',
#  '车公庄站',
#  '天宫院站',
#  '安河桥北站',
#  '天宫院站',
#  '生物医药基地站',
#  '义和庄站',
#  '黄村火车站',
#  '黄村西大街站',
#  '清源路站',
#  '枣园站',
#  '高米店南站',
#  '高米店北站',
#  '西红门站',
#  '新宫站',
#  '公益西桥站',
#  '角门西站',
#  '马家堡站',
#  '北京南站',
#  '陶然亭站',
#  '菜市口站',
#  '宣武门站',
#  '西单站',
#  '灵境胡同站',
#  '西四站',
#  '平安里站',
#  '新街口站',
#  '西直门站',
#  '动物园站',
#  '国家图书馆站',
#  '魏公村站',
#  '人民大学站',
#  '海淀黄庄站',
#  '中关村站',
#  '北京大学东门站',
#  '圆明园站',
#  '西苑站',
#  '北宫门站',
#  '安河桥北站',
#  '宋家庄站',
#  '刘家窑站',
#  '蒲黄榆站',
#  '天坛东门站',
#  '磁器口站',
#  '崇文门站',
#  '东单站',
#  '灯市口站',
#  '东四站',
#  '张自忠路站',
#  '北新桥站',
#  '雍和宫站',
#  '和平里北街站',
#  '和平西桥站',
#  '惠新西街南口站',
#  '惠新西街北口站',
#  '大屯路东站',
#  '北苑路北站',
#  '立水桥南站',
#  '立水桥站',
#  '天通苑南站',
#  '天通苑站',
#  '天通苑北站',
#  '金安桥站',
#  '苹果园站',
#  '田村站',
#  '海淀五路居站',
#  '慈寿寺站',
#  '花园桥站',
#  '白石桥南站',
#  '二里沟站',
#  '车公庄西站',
#  '车公庄站',
#  '平安里站',
#  '北海北站',
#  '南锣鼓巷站',
#  '东四站',
#  '朝阳门站',
#  '东大桥站',
#  '呼家楼站',
#  '金台路站',
#  '十里堡站',
#  '青年路站',
#  '褡裢坡站',
#  '黄渠站',
#  '常营站',
#  '草房站',
#  '物资学院路站',
#  '通州北关站',
#  '通运门站',
#  '北运河西站',
#  '北运河东站',
#  '郝家府站',
#  '东夏园站',
#  '潞城站',
#  '北京西站',
#  '湾子站',
#  '达官营站',
#  '广安门内站',
#  '菜市口站',
#  '虎坊桥站',
#  '珠市口站',
#  '桥湾站',
#  '磁器口站',
#  '广渠门内站',
#  '广渠门外站',
#  '双井站',
#  '九龙山站',
#  '大郊亭站',
#  '百子湾站',
#  '化工站',
#  '南楼梓庄站',
#  '欢乐谷景区站',
#  '垡头站',
#  '双合站',
#  '焦化厂站',
#  '豆各庄站',
#  '朱辛庄站',
#  '育知路站',
#  '平西府站',
#  '回龙观东大街站',
#  '霍营站',
#  '育新站',
#  '西小口站',
#  '永泰庄站',
#  '林萃桥站',
#  '森林公园南门站',
#  '奥林匹克公园站',
#  '奥体中心站',
#  '北土城站',
#  '安华桥站',
#  '安德里北街站',
#  '鼓楼大街站',
#  '什刹海站',
#  '南锣鼓巷站',
#  '中国美术馆站',
#  '王府井站',
#  '前门站',
#  '珠市口站',
#  '天桥站',
#  '永定门外站',
#  '木樨园站',
#  '海户屯站',
#  '大红门站',
#  '大红门南站',
#  '和义站',
#  '东高地站',
#  '火箭万源站',
#  '五福堂站',
#  '德茂站',
#  '瀛海站',
#  '郭公庄站',
#  '丰台科技园站',
#  '科怡路站',
#  '丰台南路站',
#  '丰台东大街站',
#  '七里庄站',
#  '六里桥站',
#  '六里桥东站',
#  '北京西站',
#  '军事博物馆站',
#  '白堆子站',
#  '白石桥南站',
#  '国家图书馆站',
#  '巴沟站',
#  '苏州街站',
#  '海淀黄庄站',
#  '知春里站',
#  '知春路站',
#  '西土城站',
#  '牡丹园站',
#  '健德门站',
#  '北土城站',
#  '安贞门站',
#  '惠新西街南口站',
#  '芍药居站',
#  '太阳宫站',
#  '三元桥站',
#  '亮马桥站',
#  '农业展览馆站',
#  '团结湖站',
#  '呼家楼站',
#  '金台夕照站',
#  '国贸站',
#  '双井站',
#  '劲松站',
#  '潘家园站',
#  '十里河站',
#  '分钟寺站',
#  '成寿寺站',
#  '宋家庄站',
#  '石榴庄站',
#  '大红门站',
#  '角门东站',
#  '角门西站',
#  '草桥站',
#  '纪家庙站',
#  '首经贸站',
#  '丰台站',
#  '泥洼站',
#  '西局站',
#  '六里桥站',
#  '莲花桥站',
#  '公主坟站',
#  '西钓鱼台站',
#  '慈寿寺站',
#  '车道沟站',
#  '长春桥站',
#  '火器营站',
#  '巴沟站',
#  '西直门站',
#  '大钟寺站',
#  '知春路站',
#  '五道口站',
#  '清华东路西口站',
#  '上地站',
#  '清河站',
#  '西二旗站',
#  '龙泽站',
#  '回龙观站',
#  '霍营站',
#  '建材城东路站',
#  '立水桥站',
#  '北苑站',
#  '望京西站',
#  '芍药居站',
#  '光熙门站',
#  '柳芳站',
#  '东直门站',
#  '园博园站',
#  '大瓦窑站',
#  '郭庄子站',
#  '大井站',
#  '七里庄站',
#  '西局站',
#  '丽泽商务区站',
#  '北京南站',
#  '陶然桥站',
#  '永定门外站',
#  '景泰站',
#  '蒲黄榆站',
#  '方庄站',
#  '十里河站',
#  '北工大西门站',
#  '平乐园站',
#  '九龙山站',
#  '大望路站',
#  '金台路站',
#  '朝阳公园站',
#  '枣营站',
#  '东风北桥站',
#  '将台站',
#  '高家园站',
#  '望京南站',
#  '阜通站',
#  '望京站',
#  '东湖渠站',
#  '来广营站',
#  '善各庄站',
#  '清华东路西口站',
#  '六道口站',
#  '北沙滩站',
#  '奥林匹克公园站',
#  '安立路站',
#  '大屯路东站',
#  '关庄站',
#  '望京西站',
#  '望京站',
#  '望京东站',
#  '崔各庄站',
#  '马泉营站',
#  '孙河站',
#  '国展站',
#  '花梨坎站',
#  '后沙峪站',
#  '南法信站',
#  '石门站',
#  '顺义站',
#  '俸伯站',
#  '四惠站',
#  '四惠东站',
#  '高碑店站',
#  '传媒大学站',
#  '双桥站',
#  '管庄站',
#  '八里桥站',
#  '通州北苑站',
#  '果园站',
#  '九棵树站',
#  '梨园站',
#  '临河里站',
#  '土桥站',
#  '环球影城站',
#  '西二旗站',
#  '生命科学园站',
#  '朱辛庄站',
#  '巩华城站',
#  '沙河站',
#  '沙河高教园站',
#  '南邵站',
#  '北邵洼站',
#  '昌平东关站',
#  '昌平站',
#  '昌平北站',
#  '十三陵景区站',
#  '昌平西山口站',
#  '亦庄火车站',
#  '次渠站',
#  '次渠南站',
#  '经海路站',
#  '同济南路站',
#  '荣昌东街站',
#  '荣京东街站',
#  '万源街站',
#  '亦庄文化园站',
#  '亦庄桥站',
#  '旧宫站',
#  '小红门站',
#  '肖村站',
#  '宋家庄站',
#  '阎村东站',
#  '苏庄站',
#  '良乡南关站',
#  '良乡大学城西站',
#  '良乡大学城站',
#  '良乡大学城北站',
#  '广阳城站',
#  '篱笆房站',
#  '长阳站',
#  '稻田站',
#  '大葆台站',
#  '郭公庄站',
#  '首经贸站',
#  '丰益桥南站']

# %%
all_stations=set(allstations)
len(all_stations)
# Out:
# 309

# %%
def distance(element1,element2):
    for sublist in l:
        if element1 in sublist and element2 in sublist:
            return abs(sublist.index(element1)-sublist.index(element2))

# %%
from collections import defaultdict
stations_connection=defaultdict(list)

for station_one in all_stations:
    for station_two in all_stations:
        if station_one==station_two:continue
        if distance(station_one,station_two)==1:
            stations_connection[station_one].append(station_two)
##得到graph，所有站连接的图
stations_connection
# Out:
# defaultdict(list,
#             {'大郊亭站': ['九龙山站', '百子湾站'],
#              '霍营站': ['育新站', '建材城东路站', '回龙观东大街站', '回龙观站'],
#              '泥洼站': ['西局站', '丰台站'],
#              '白石桥南站': ['国家图书馆站', '二里沟站', '白堆子站', '花园桥站'],
#              '知春里站': ['知春路站', '海淀黄庄站'],
#              '北京西站': ['湾子站', '六里桥东站', '军事博物馆站'],
#              '奥林匹克公园站': ['北沙滩站', '森林公园南门站', '安立路站', '奥体中心站'],
#              '车公庄站': ['阜成门站', '车公庄西站', '平安里站'],
#              '双合站': ['焦化厂站', '垡头站'],
#              '丽泽商务区站': ['北京南站', '西局站'],
#              '丰台科技园站': ['郭公庄站', '科怡路站'],
#              '草桥站': ['纪家庙站', '角门西站'],
#              '物资学院路站': ['通州北关站', '草房站'],
#              '四惠站': ['大望路站', '四惠东站'],
#              '大葆台站': ['郭公庄站', '稻田站'],
#              '平乐园站': ['九龙山站', '北工大西门站'],
#              '阜通站': ['望京站', '望京南站'],
#              '北京南站': ['丽泽商务区站', '陶然桥站', '陶然亭站', '马家堡站'],
#              '大瓦窑站': ['郭庄子站', '园博园站'],
#              '通州北关站': ['物资学院路站', '通运门站'],
#              '太阳宫站': ['三元桥站', '芍药居站'],
#              '大红门站': ['海户屯站', '角门东站', '石榴庄站', '大红门南站'],
#              '郭公庄站': ['丰台科技园站', '大葆台站', '首经贸站'],
#              '首经贸站': ['郭公庄站', '丰益桥南站', '纪家庙站', '丰台站'],
#              '西苑站': ['圆明园站', '北宫门站'],
#              '公益西桥站': ['新宫站', '角门西站'],
#              '广阳城站': ['篱笆房站', '良乡大学城北站'],
#              '和义站': ['东高地站', '大红门南站'],
#              '崔各庄站': ['望京东站', '马泉营站'],
#              '朝阳公园站': ['金台路站', '枣营站'],
#              '土桥站': ['临河里站', '环球影城站'],
#              '苏州街站': ['巴沟站', '海淀黄庄站'],
#              '九龙山站': ['大郊亭站', '平乐园站', '大望路站', '双井站'],
#              '七里庄站': ['六里桥站', '西局站', '大井站', '丰台东大街站'],
#              '高米店南站': ['高米店北站', '枣园站'],
#              '海户屯站': ['大红门站', '木樨园站'],
#              '稻田站': ['大葆台站', '长阳站'],
#              '西二旗站': ['生命科学园站', '龙泽站', '清河站'],
#              '国家图书馆站': ['白石桥南站', '魏公村站', '动物园站'],
#              '木樨地站': ['南礼士路站', '军事博物馆站'],
#              '化工站': ['百子湾站', '南楼梓庄站'],
#              '天桥站': ['珠市口站', '永定门外站'],
#              '石门站': ['南法信站', '顺义站'],
#              '人民大学站': ['魏公村站', '海淀黄庄站'],
#              '亦庄桥站': ['亦庄文化园站', '旧宫站'],
#              '郭庄子站': ['大瓦窑站', '大井站'],
#              '育新站': ['霍营站', '西小口站'],
#              '高碑店站': ['四惠东站', '传媒大学站'],
#              '丰益桥南站': ['首经贸站'],
#              '长春桥站': ['火器营站', '车道沟站'],
#              '复兴门站': ['长椿街站', '阜成门站', '南礼士路站', '西单站'],
#              '欢乐谷景区站': ['南楼梓庄站', '垡头站'],
#              '景泰站': ['蒲黄榆站', '永定门外站'],
#              '田村站': ['苹果园站', '海淀五路居站'],
#              '东四十条站': ['朝阳门站', '东直门站'],
#              '高米店北站': ['高米店南站', '西红门站'],
#              '俸伯站': ['顺义站'],
#              '宣武门站': ['长椿街站', '菜市口站', '和平门站', '西单站'],
#              '劲松站': ['潘家园站', '双井站'],
#              '北海北站': ['平安里站', '南锣鼓巷站'],
#              '大望路站': ['四惠站', '九龙山站', '金台路站', '国贸站'],
#              '三元桥站': ['太阳宫站', '亮马桥站'],
#              '角门东站': ['大红门站', '角门西站'],
#              '北土城站': ['健德门站', '安华桥站', '安贞门站', '奥体中心站'],
#              '北工大西门站': ['平乐园站', '十里河站'],
#              '建材城东路站': ['霍营站', '立水桥站'],
#              '方庄站': ['蒲黄榆站', '十里河站'],
#              '广安门内站': ['菜市口站', '达官营站'],
#              '木樨园站': ['海户屯站', '永定门外站'],
#              '北沙滩站': ['奥林匹克公园站', '六道口站'],
#              '朝阳门站': ['东四十条站', '东大桥站', '东四站', '建国门站'],
#              '常营站': ['草房站', '黄渠站'],
#              '西红门站': ['高米店北站', '新宫站'],
#              '南法信站': ['石门站', '后沙峪站'],
#              '火箭万源站': ['五福堂站', '东高地站'],
#              '纪家庙站': ['草桥站', '首经贸站'],
#              '新宫站': ['公益西桥站', '西红门站'],
#              '安德里北街站': ['安华桥站', '鼓楼大街站'],
#              '农业展览馆站': ['亮马桥站', '团结湖站'],
#              '北苑路北站': ['立水桥南站', '大屯路东站'],
#              '朱辛庄站': ['生命科学园站', '巩华城站', '育知路站'],
#              '天安门东站': ['王府井站', '天安门西站'],
#              '六里桥站': ['七里庄站', '西局站', '莲花桥站', '六里桥东站'],
#              '天宫院站': ['安河桥北站'],
#              '北运河西站': ['北运河东站', '通运门站'],
#              '长椿街站': ['复兴门站', '宣武门站'],
#              '积水潭站': ['西直门站', '鼓楼大街站'],
#              '黄村西大街站': ['清源路站', '黄村火车站'],
#              '芍药居站': ['太阳宫站', '望京西站', '光熙门站', '惠新西街南口站'],
#              '和平西桥站': ['惠新西街南口站', '和平里北街站'],
#              '柳芳站': ['东直门站', '光熙门站'],
#              '望京西站': ['芍药居站', '望京站', '北苑站', '关庄站'],
#              '北京大学东门站': ['圆明园站', '中关村站'],
#              '回龙观东大街站': ['霍营站', '平西府站'],
#              '苹果园站': ['田村站', '金安桥站', '古城站', '福寿岭站'],
#              '梨园站': ['临河里站', '九棵树站'],
#              '安定门站': ['鼓楼大街站', '雍和宫站'],
#              '广渠门外站': ['双井站', '广渠门内站'],
#              '菜市口站': ['宣武门站', '广安门内站', '虎坊桥站', '陶然亭站'],
#              '张自忠路站': ['东四站', '北新桥站'],
#              '金安桥站': ['苹果园站'],
#              '西局站': ['泥洼站', '丽泽商务区站', '七里庄站', '六里桥站'],
#              '东直门站': ['东四十条站', '柳芳站', '雍和宫站'],
#              '东风北桥站': ['枣营站', '将台站'],
#              '亦庄文化园站': ['亦庄桥站', '万源街站'],
#              '二里沟站': ['白石桥南站', '车公庄西站'],
#              '王府井站': ['天安门东站', '中国美术馆站', '东单站', '前门站'],
#              '同济南路站': ['荣昌东街站', '经海路站'],
#              '呼家楼站': ['东大桥站', '金台路站', '团结湖站', '金台夕照站'],
#              '东大桥站': ['朝阳门站', '呼家楼站'],
#              '新街口站': ['平安里站', '西直门站'],
#              '生命科学园站': ['西二旗站', '朱辛庄站'],
#              '德茂站': ['五福堂站', '瀛海站'],
#              '阜成门站': ['车公庄站', '复兴门站'],
#              '健德门站': ['北土城站', '牡丹园站'],
#              '天通苑南站': ['天通苑站', '立水桥站'],
#              '花梨坎站': ['后沙峪站', '国展站'],
#              '巩华城站': ['朱辛庄站', '沙河站'],
#              '莲花桥站': ['六里桥站', '公主坟站'],
#              '蒲黄榆站': ['景泰站', '方庄站', '刘家窑站', '天坛东门站'],
#              '森林公园南门站': ['奥林匹克公园站', '林萃桥站'],
#              '湾子站': ['北京西站', '达官营站'],
#              '管庄站': ['八里桥站', '双桥站'],
#              '潘家园站': ['劲松站', '十里河站'],
#              '次渠南站': ['次渠站', '经海路站'],
#              '南邵站': ['沙河高教园站', '北邵洼站'],
#              '双井站': ['九龙山站', '劲松站', '广渠门外站', '国贸站'],
#              '巴沟站': ['苏州街站'],
#              '立水桥南站': ['北苑路北站', '立水桥站'],
#              '黑石头站': ['高井站'],
#              '林萃桥站': ['森林公园南门站', '永泰庄站'],
#              '古城站': ['苹果园站', '八角游乐园站'],
#              '后沙峪站': ['南法信站', '花梨坎站'],
#              '和平门站': ['宣武门站', '前门站'],
#              '成寿寺站': ['分钟寺站', '宋家庄站'],
#              '东四站': ['朝阳门站', '张自忠路站', '灯市口站', '南锣鼓巷站'],
#              '崇文门站': ['磁器口站', '东单站', '前门站', '北京站'],
#              '生物医药基地站': ['义和庄站'],
#              '福寿岭站': ['苹果园站', '高井站'],
#              '磁器口站': ['崇文门站', '广渠门内站', '天坛东门站', '桥湾站'],
#              '六里桥东站': ['北京西站', '六里桥站'],
#              '通州北苑站': ['果园站', '八里桥站'],
#              '龙泽站': ['西二旗站', '回龙观站'],
#              '枣园站': ['高米店南站', '清源路站'],
#              '中国美术馆站': ['王府井站', '南锣鼓巷站'],
#              '良乡大学城西站': ['良乡南关站', '良乡大学城站'],
#              '刘家窑站': ['蒲黄榆站', '宋家庄站'],
#              '良乡南关站': ['良乡大学城西站', '苏庄站'],
#              '什刹海站': ['南锣鼓巷站', '鼓楼大街站'],
#              '玉泉路站': ['八宝山站', '五棵松站'],
#              '篱笆房站': ['广阳城站', '长阳站'],
#              '西四站': ['灵境胡同站', '平安里站'],
#              '石榴庄站': ['大红门站', '宋家庄站'],
#              '大井站': ['七里庄站', '郭庄子站'],
#              '灵境胡同站': ['西四站', '西单站'],
#              '次渠站': ['次渠南站', '亦庄火车站'],
#              '十里河站': ['北工大西门站', '方庄站', '潘家园站', '分钟寺站'],
#              '来广营站': ['东湖渠站', '善各庄站'],
#              '望京站': ['阜通站', '望京西站', '望京东站', '东湖渠站'],
#              '望京东站': ['崔各庄站', '望京站'],
#              '分钟寺站': ['成寿寺站', '十里河站'],
#              '光熙门站': ['芍药居站', '柳芳站'],
#              '肖村站': ['宋家庄站', '小红门站'],
#              '宋家庄站': ['成寿寺站', '刘家窑站', '石榴庄站', '肖村站'],
#              '金台路站': ['朝阳公园站', '大望路站', '呼家楼站', '十里堡站'],
#              '惠新西街南口站': ['芍药居站', '和平西桥站', '安贞门站', '惠新西街北口站'],
#              '广渠门内站': ['广渠门外站', '磁器口站'],
#              '五福堂站': ['火箭万源站', '德茂站'],
#              '丰台东大街站': ['七里庄站', '丰台南路站'],
#              '马泉营站': ['崔各庄站', '孙河站'],
#              '国贸站': ['大望路站', '双井站', '永安里站', '金台夕照站'],
#              '安河桥北站': ['天宫院站'],
#              '四惠东站': ['四惠站', '高碑店站'],
#              '车公庄西站': ['车公庄站', '二里沟站'],
#              '平西府站': ['回龙观东大街站', '育知路站'],
#              '西小口站': ['育新站', '永泰庄站'],
#              '亮马桥站': ['三元桥站', '农业展览馆站'],
#              '回龙观站': ['霍营站', '龙泽站'],
#              '魏公村站': ['国家图书馆站', '人民大学站'],
#              '万寿路站': ['公主坟站', '五棵松站'],
#              '上地站': ['清河站', '清华东路西口站'],
#              '北运河东站': ['北运河西站', '郝家府站'],
#              '昌平东关站': ['昌平站', '北邵洼站'],
#              '清源路站': ['黄村西大街站', '枣园站'],
#              '良乡大学城站': ['良乡大学城西站', '良乡大学城北站'],
#              '十里堡站': ['金台路站', '青年路站'],
#              '东单站': ['王府井站', '崇文门站', '灯市口站', '建国门站'],
#              '东高地站': ['和义站', '火箭万源站'],
#              '灯市口站': ['东四站', '东单站'],
#              '八宝山站': ['玉泉路站', '八角游乐园站'],
#              '南礼士路站': ['木樨地站', '复兴门站'],
#              '褡裢坡站': ['黄渠站', '青年路站'],
#              '知春路站': ['知春里站', '五道口站', '大钟寺站', '西土城站'],
#              '百子湾站': ['大郊亭站', '化工站'],
#              '良乡大学城北站': ['广阳城站', '良乡大学城站'],
#              '草房站': ['物资学院路站', '常营站'],
#              '苏庄站': ['良乡南关站', '阎村东站'],
#              '孙河站': ['马泉营站', '国展站'],
#              '临河里站': ['土桥站', '梨园站'],
#              '西单站': ['复兴门站', '宣武门站', '灵境胡同站', '天安门西站'],
#              '动物园站': ['国家图书馆站', '西直门站'],
#              '高家园站': ['望京南站', '将台站'],
#              '永泰庄站': ['林萃桥站', '西小口站'],
#              '沙河站': ['巩华城站', '沙河高教园站'],
#              '天安门西站': ['天安门东站', '西单站'],
#              '海淀黄庄站': ['知春里站', '苏州街站', '人民大学站', '中关村站'],
#              '传媒大学站': ['高碑店站', '双桥站'],
#              '万源街站': ['亦庄文化园站', '荣京东街站'],
#              '天通苑北站': ['天通苑站'],
#              '团结湖站': ['农业展览馆站', '呼家楼站'],
#              '慈寿寺站': ['西钓鱼台站', '海淀五路居站', '花园桥站', '车道沟站'],
#              '清河站': ['西二旗站', '上地站'],
#              '郝家府站': ['北运河东站', '东夏园站'],
#              '公主坟站': ['莲花桥站', '万寿路站', '西钓鱼台站', '军事博物馆站'],
#              '北苑站': ['望京西站', '立水桥站'],
#              '阎村东站': ['苏庄站'],
#              '和平里北街站': ['和平西桥站', '雍和宫站'],
#              '荣昌东街站': ['同济南路站', '荣京东街站'],
#              '黄渠站': ['常营站', '褡裢坡站'],
#              '虎坊桥站': ['菜市口站', '珠市口站'],
#              '平安里站': ['车公庄站', '北海北站', '新街口站', '西四站'],
#              '经海路站': ['同济南路站', '次渠南站'],
#              '南楼梓庄站': ['化工站', '欢乐谷景区站'],
#              '环球影城站': ['土桥站'],
#              '牡丹园站': ['健德门站', '西土城站'],
#              '角门西站': ['草桥站', '公益西桥站', '角门东站', '马家堡站'],
#              '昌平西山口站': ['十三陵景区站'],
#              '陶然桥站': ['北京南站', '永定门外站'],
#              '天坛东门站': ['蒲黄榆站', '磁器口站'],
#              '建国门站': ['朝阳门站', '东单站', '永安里站', '北京站'],
#              '西钓鱼台站': ['慈寿寺站', '公主坟站'],
#              '通运门站': ['通州北关站', '北运河西站'],
#              '圆明园站': ['西苑站', '北京大学东门站'],
#              '五棵松站': ['玉泉路站', '万寿路站'],
#              '青年路站': ['十里堡站', '褡裢坡站'],
#              '白堆子站': ['白石桥南站', '军事博物馆站'],
#              '安华桥站': ['北土城站', '安德里北街站'],
#              '军事博物馆站': ['北京西站', '木樨地站', '公主坟站', '白堆子站'],
#              '前门站': ['王府井站', '和平门站', '崇文门站', '珠市口站'],
#              '北宫门站': ['西苑站'],
#              '天通苑站': ['天通苑南站', '天通苑北站'],
#              '昌平站': ['昌平东关站', '昌平北站'],
#              '陶然亭站': ['北京南站', '菜市口站'],
#              '中关村站': ['北京大学东门站', '海淀黄庄站'],
#              '瀛海站': ['德茂站'],
#              '安贞门站': ['北土城站', '惠新西街南口站'],
#              '焦化厂站': ['双合站', '豆各庄站'],
#              '桥湾站': ['磁器口站', '珠市口站'],
#              '清华东路西口站': ['上地站', '六道口站', '五道口站'],
#              '西直门站': ['积水潭站', '新街口站', '动物园站', '大钟寺站'],
#              '果园站': ['通州北苑站', '九棵树站'],
#              '海淀五路居站': ['田村站', '慈寿寺站'],
#              '六道口站': ['北沙滩站', '清华东路西口站'],
#              '大红门南站': ['大红门站', '和义站'],
#              '南锣鼓巷站': ['北海北站', '东四站', '中国美术馆站', '什刹海站'],
#              '五道口站': ['知春路站', '清华东路西口站'],
#              '达官营站': ['广安门内站', '湾子站'],
#              '旧宫站': ['亦庄桥站', '小红门站'],
#              '丰台南路站': ['丰台东大街站', '科怡路站'],
#              '望京南站': ['阜通站', '高家园站'],
#              '丰台站': ['泥洼站', '首经贸站'],
#              '潞城站': ['东夏园站'],
#              '东湖渠站': ['来广营站', '望京站'],
#              '安立路站': ['奥林匹克公园站', '大屯路东站'],
#              '奥体中心站': ['奥林匹克公园站', '北土城站'],
#              '荣京东街站': ['万源街站', '荣昌东街站'],
#              '珠市口站': ['天桥站', '虎坊桥站', '前门站', '桥湾站'],
#              '育知路站': ['朱辛庄站', '平西府站'],
#              '小红门站': ['肖村站', '旧宫站'],
#              '科怡路站': ['丰台科技园站', '丰台南路站'],
#              '八里桥站': ['管庄站', '通州北苑站'],
#              '枣营站': ['朝阳公园站', '东风北桥站'],
#              '北新桥站': ['张自忠路站', '雍和宫站'],
#              '东夏园站': ['郝家府站', '潞城站'],
#              '惠新西街北口站': ['惠新西街南口站', '大屯路东站'],
#              '亦庄火车站': ['次渠站'],
#              '将台站': ['东风北桥站', '高家园站'],
#              '九棵树站': ['梨园站', '果园站'],
#              '昌平北站': ['昌平站', '十三陵景区站'],
#              '关庄站': ['望京西站', '大屯路东站'],
#              '长阳站': ['稻田站', '篱笆房站'],
#              '鼓楼大街站': ['安德里北街站', '积水潭站', '安定门站', '什刹海站'],
#              '立水桥站': ['建材城东路站', '天通苑南站', '立水桥南站', '北苑站'],
#              '顺义站': ['石门站', '俸伯站'],
#              '火器营站': ['长春桥站'],
#              '善各庄站': ['来广营站'],
#              '永安里站': ['国贸站', '建国门站'],
#              '沙河高教园站': ['南邵站', '沙河站'],
#              '双桥站': ['管庄站', '传媒大学站'],
#              '垡头站': ['双合站', '欢乐谷景区站'],
#              '大钟寺站': ['知春路站', '西直门站'],
#              '义和庄站': ['生物医药基地站', '黄村火车站'],
#              '花园桥站': ['白石桥南站', '慈寿寺站'],
#              '马家堡站': ['北京南站', '角门西站'],
#              '园博园站': ['大瓦窑站'],
#              '车道沟站': ['长春桥站', '慈寿寺站'],
#              '八角游乐园站': ['古城站', '八宝山站'],
#              '十三陵景区站': ['昌平西山口站', '昌平北站'],
#              '雍和宫站': ['安定门站', '东直门站', '和平里北街站', '北新桥站'],
#              '永定门外站': ['天桥站', '景泰站', '木樨园站', '陶然桥站'],
#              '豆各庄站': ['焦化厂站'],
#              '国展站': ['花梨坎站', '孙河站'],
#              '北邵洼站': ['南邵站', '昌平东关站'],
#              '金台夕照站': ['呼家楼站', '国贸站'],
#              '北京站': ['崇文门站', '建国门站'],
#              '西土城站': ['知春路站', '牡丹园站'],
#              '大屯路东站': ['北苑路北站', '安立路站', '惠新西街北口站', '关庄站'],
#              '高井站': ['黑石头站', '福寿岭站'],
#              '黄村火车站': ['黄村西大街站', '义和庄站']})

# %%
stations_connection_graph=nx.Graph(stations_connection)
nx.draw(stations_connection_graph,with_labels=True,node_size=30)
# Out:
# /Users/kaifeng/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
def search_destination(graph, start, get_succsssors, is_goal_predicate, strategy_func):
    pathes = [[start]]
    seen = set()
    chosen_pathes = []
    while pathes:
        path = pathes.pop(0)
        frontier = path[-1]
        if frontier in seen: continue
            
        for city in get_succsssors(frontier, graph):
            if city in path: continue # remove the loop
            new_path = path + [city]
            pathes.append(new_path)
            if is_goal_predicate(city): return new_path
        
        pathes = strategy_func(pathes)
        seen.add(frontier)
    return chosen_pathes

# %%
def get_succsssors(froninter, graph):
    return graph[froninter]

# %%
def is_goal(node, destination): 
    return node ==  destination

# %%
def sort_pathes(pathes, func,beam):
    return sorted(pathes, key=func)[:beam]

# %%
#这里假设每组相邻站之间距离差不多
def shortest_path_priority(pathes):
    return sort_pathes(pathes, lambda p:len(p), beam=30)

# %%
#最少换乘地铁，用path里相隔两个位置的元素判断
def mininum_change_station(pathes):
    return sort_pathes(pathes, lambda p: number_lines(p), beam=30)

# %%
def comprehensive_sort(pathes):
    return sort_pathes(pathes, lambda p: (len(p) + number_lines(p)), beam=30)

# %%
def number_lines(path):
    lines=0
    if len(path)==2:return 0
    for i in range(len(path)-1):
        if i==0:continue
        lines+=line_transfer(path[i-1],path[i+1])
    return lines

def line_transfer(a,b):
    for sublist in l:
        if a in sublist and b in sublist:return 0
    return 1

# %%
search_destination(stations_connection_graph,'首经贸站',get_succsssors, lambda n: n =='西二旗站',mininum_change_station)
# Out:
# ['首经贸站',
#  '纪家庙站',
#  '草桥站',
#  '角门西站',
#  '角门东站',
#  '大红门站',
#  '石榴庄站',
#  '宋家庄站',
#  '成寿寺站',
#  '分钟寺站',
#  '十里河站',
#  '潘家园站',
#  '劲松站',
#  '双井站',
#  '国贸站',
#  '金台夕照站',
#  '呼家楼站',
#  '团结湖站',
#  '农业展览馆站',
#  '亮马桥站',
#  '三元桥站',
#  '太阳宫站',
#  '芍药居站',
#  '望京西站',
#  '北苑站',
#  '立水桥站',
#  '建材城东路站',
#  '霍营站',
#  '回龙观站',
#  '龙泽站',
#  '西二旗站']

# %%
search_destination(stations_connection_graph,'首经贸站',get_succsssors, lambda n: n =='西二旗站',shortest_path_priority)
# Out:
# ['首经贸站',
#  '丰台站',
#  '泥洼站',
#  '西局站',
#  '六里桥站',
#  '莲花桥站',
#  '公主坟站',
#  '军事博物馆站',
#  '白堆子站',
#  '白石桥南站',
#  '国家图书馆站',
#  '动物园站',
#  '西直门站',
#  '大钟寺站',
#  '知春路站',
#  '五道口站',
#  '清华东路西口站',
#  '上地站',
#  '清河站',
#  '西二旗站']

# %%
search_destination(stations_connection_graph,'首经贸站',get_succsssors, lambda n: n =='西二旗站',comprehensive_sort)
# Out:
# ['首经贸站',
#  '丰台站',
#  '泥洼站',
#  '西局站',
#  '六里桥站',
#  '莲花桥站',
#  '公主坟站',
#  '军事博物馆站',
#  '白堆子站',
#  '白石桥南站',
#  '国家图书馆站',
#  '动物园站',
#  '西直门站',
#  '大钟寺站',
#  '知春路站',
#  '五道口站',
#  '清华东路西口站',
#  '上地站',
#  '清河站',
#  '西二旗站']
